# %%
import pandas as pd
from pathlib import Path
import hashlib

def create_parquet_from_png_and_txt(image_dir, output_path="dataset.parquet"):
    image_dir = Path(image_dir)
    data = []
    
    # Assumindo que cada imagem tem um txt com o mesmo nome (ex: img1.png, img1.txt)
    for img_path in sorted(image_dir.glob("*.jpg")):
        txt_path = img_path.with_suffix('.txt')
        if txt_path.exists():
            with open(txt_path, "r", encoding="utf-8") as f:
                label = f.read().strip()
        else:
            label = ""
        
        # Gerar hash SHA256 da imagem
        with open(img_path, "rb") as f:
            image_hash = hashlib.sha256(f.read()).hexdigest()
        
        data.append({
            "image_path": str(img_path.resolve()),
            "label": label,
            "image_hash": image_hash
        })
    
    df = pd.DataFrame(data)
    df.to_parquet(output_path)
    print(f"✅ Parquet criado: {output_path}")
    print(df.head())

# Exemplo de uso:
# create_parquet_from_png_and_txt("data/van_gogh", "van_gogh_png_labels.parquet")

# %%
create_parquet_from_png_and_txt("vangogh/portrait", "vangogh_portrait.parquet")
# Out:
# ✅ Parquet criado: vangogh_portrait.parquet
#                                           image_path  \
# 0  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 1  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 2  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 3  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 4  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
#
#                                                label  \
# 0  Autorretrato com chapéu de palha amarelo, barb...
# 1  Homem melancólico de boné branco apoiado na mã...
# 2  Homem de barba e casaco azul contra papel de p...
# 3  Mulher apoiando o rosto na mão, roupas escuras...
# 4  Autorretrato com orelha enfaixada, casaco verd...
#
#                                           image_hash
# 0  4a887e62ececdda83d1abe6c3d940b7627e9253009cf06...
# 1  3f65c2ea37c05d834cc37cecb0525e9910fa717223e019...
# 2  f34f69ae5a69a7189e20f7c5bc9e733b00c8aeb24db9fe...
# 3  9cf974ef5726365511600540db989594c1ee8341e62a56...
# 4  a86f76a71185a3a6d60fda2a8db5be065204851571332a...

# %%
create_parquet_from_png_and_txt("vangogh/style", "vangogh_style.parquet")
# Out:
# ✅ Parquet criado: vangogh_style.parquet
#                                           image_path  \
# 0  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 1  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 2  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 3  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
# 4  /home/jmvjr/Documentos/unicamp/MC949/Generativ...
#
#                                                label  \
# 0  Ramo de amendoeira em flor em um copo d'água t...
# 1  Terraço de café iluminado com luz amarela quen...
# 2  Colheita em vinhedo vermelho e laranja ao pôr ...
# 3  Doze girassóis amarelos vibrantes em um vaso d...
# 4  Ponte de pedra sobre o rio Sena com reflexos n...
#
#                                           image_hash
# 0  5b5a339047daf803b321cb138fb6d3c312e0c9edc6d2d5...
# 1  187ed67881e978a90cf31a539fd8a93942b0574b15d145...
# 2  02d76160eb4b602ac9e9847dffe620ae28da109ce0033d...
# 3  d2ced3bd0adfd362898e4155d5bd730df786ea19d8bd43...
# 4  5c1bdfae96992a2a090ee8e717063e6fd472a0c8124a35...

# %%
from PIL import Image
from pathlib import Path
def resize_images_in_parquet(parquet_path, size=(512, 512)):
    import pandas as pd
    df = pd.read_parquet(parquet_path)
    # Apenas redimensiona em memória, não salva nem altera os caminhos
    for idx, row in df.iterrows():
        img_path = row['image_path']
        img = Image.open(img_path)
        img = img.convert("RGB")
        img_resized = img.resize(size, Image.LANCZOS)
        # Se quiser salvar, adicione aqui, mas por padrão só processa
    # Mantém os caminhos originais no parquet
    df.to_parquet(parquet_path.replace(".parquet", "_resized.parquet"))
    print(f"✅ Parquet salvo (caminhos originais): {parquet_path.replace('.parquet', '_resized.parquet')}")

# %%
resize_images_in_parquet("vangogh_portrait.parquet", size=(512, 512))
resize_images_in_parquet("vangogh_style.parquet", size=(512, 512))
# Out:
# ✅ Parquet salvo (caminhos originais): vangogh_portrait_resized.parquet
# ✅ Parquet salvo (caminhos originais): vangogh_style_resized.parquet
